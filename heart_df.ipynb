# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/dataset.csv"
heart_df = pd.read_csv(csv_file)
heart_df.head(100)
# Out:
#     Year LocationAbbr LocationDesc Datasource PriorityArea1 PriorityArea2  \
# 0   2011           AL      Alabama      BRFSS          None          None
# 1   2011           AL      Alabama      BRFSS          None          None
# 2   2011           AL      Alabama      BRFSS          None          None
# 3   2011           AL      Alabama      BRFSS          None          None
# 4   2011           AL      Alabama      BRFSS          None          None
# 5   2011           AL      Alabama      BRFSS          None          None
# 6   2011           AL      Alabama      BRFSS          None          None
# 7   2011           AL      Alabama      BRFSS          None          None
# 8   2011           AL      Alabama      BRFSS          None          None
# 9   2011           AL      Alabama      BRFSS          None          None
# 10  2011           AL      Alabama      BRFSS          None          None
# 11  2011           AL      Alabama      BRFSS          None          None
# ...

# %%
#listing all columns available in this resource to determine if there are any that we want to drop
list(heart_df.columns.values)
# Out:
# ['Year',
#  'LocationAbbr',
#  'LocationDesc',
#  'Datasource',
#  'PriorityArea1',
#  'PriorityArea2',
#  'PriorityArea3',
#  'PriorityArea4',
#  'Category',
#  'Topic',
#  'Indicator',
#  'Data_Value_Type',
#  'Data_Value_Unit',
#  'Data_Value',
#  'Data_Value_Alt',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Confidence_Limit_Low',
#  'Confidence_Limit_High',
#  'Break_Out_Category',
#  'Break_out',
#  'CategoryID',
#  'TopicID',
#  'IndicatorID',
#  'Data_Value_TypeID',
#  'BreakoutCategoryID',
#  'BreakOutID',
#  'LocationID',
#  'GeoLocation']

# %%
#drop LocationAbbr
#drop GeoLocation

# %%
heart_df = heart_df.drop(columns=["LocationAbbr", "GeoLocation"])

# %%
heart_df.head()
# Out:
#    Year LocationDesc Datasource PriorityArea1 PriorityArea2 PriorityArea3  \
# 0  2011      Alabama      BRFSS          None          None          None
# 1  2011      Alabama      BRFSS          None          None          None
# 2  2011      Alabama      BRFSS          None          None          None
# 3  2011      Alabama      BRFSS          None          None          None
# 4  2011      Alabama      BRFSS          None          None          None
#
#   PriorityArea4                 Category                         Topic  \
# 0          None  Cardiovascular Diseases  Major Cardiovascular Disease
# 1          None  Cardiovascular Diseases  Major Cardiovascular Disease
# 2          None  Cardiovascular Diseases  Major Cardiovascular Disease
# 3          None  Cardiovascular Diseases  Major Cardiovascular Disease
# 4          None  Cardiovascular Diseases  Major Cardiovascular Disease
#
#                                            Indicator    ...      \
# ...
